# %%
import random
import math

class HelloGenetic:
  def __init__(self, params):
    self.ALL_CHARACTERS = list("qwertyuiopasdfghjklñzxcvbnmQWERTYUIOPASDFGHJKLÑZXCVBNM. ,!¡")
    self.HELLO_WORLD = list("Hello, world!")
    self.params = params
    self.specimen = [None] * self.params["generation_size"]

    self.create_initial_population()

  def create_initial_population(self):
    self.specimen = list(map(lambda _: random.sample(self.ALL_CHARACTERS, len(self.HELLO_WORLD)), self.specimen))

  def fitness(self, specimen):
    return sum(1 for expected, actual in zip(self.HELLO_WORLD, specimen) if expected == actual) / len(self.HELLO_WORLD)

  def is_converged(self):
    if any(self.fitness(specimen) >= self.params["fit_threshold"] for specimen in self.specimen):
      return True

    return False

  def get_fit(self):
    evaluations = self.fitness_all()

    max_evaluation = max(evaluations)

    max_index = evaluations.index(max_evaluation)

    return self.specimen[max_index], max_evaluation

  def fitness_all(self):
    return list(map(self.fitness, self.specimen))

  def select_specimen(self, specimen_evaluations):
    specimen_and_evaluations = list(zip(self.specimen, specimen_evaluations))

    specimen_and_evaluations.sort(key=lambda e: e[1], reverse = True) 

    n_top = int(math.ceil(len(self.specimen) * params["select_top"]))

    return list(map(lambda s: s[0], specimen_and_evaluations[:n_top]))
  
  def mutate(self, specimen):
    n_digits = int(params["mutation_percentage"] * (len(specimen) - 1))

    digit_indexes = random.sample(list(range(len(specimen))), n_digits)

    mutated = specimen[:]

    for idx in digit_indexes:
      mutated[idx] = random.choice(self.ALL_CHARACTERS)

    return mutated

  def generate_children(self, selected_specimen):  
    mutated_specimen = [None] * len(self.specimen)

    for i in range(len(mutated_specimen)):
      mutated_specimen[i] = self.mutate(random.choice(selected_specimen))

    return mutated_specimen

  def run(self):
    generation_number = 1

    while generation_number <= self.params["max_generations"] and not self.is_converged():
      top_generation = self.get_fit()
      top_str = "".join(top_generation[0])
      
      print(f"Generation #{generation_number}:\t{top_str}\t{top_generation[1]}")

      specimen_evaluations = self.fitness_all()
      selected_specimen = self.select_specimen(specimen_evaluations)
      
      self.specimen = self.generate_children(selected_specimen)
      
      generation_number += 1
    
    return self.get_fit()

# %%
params = {
    "mutation_percentage": 0.1,
    "select_top": 0.05,
    "generation_size": 20,
    "fit_threshold": 1,
    "max_generations": 1000
}

hello = HelloGenetic(params)
fit  = hello.run()

print("".join(fit[0]), fit[1])
# Out:
# Generation #1:	W,ReNQZroiKJL	0.07692307692307693
# Generation #2:	W,ReNQZUoiKJL	0.07692307692307693
# Generation #3:	W,ReNQZUoiKrL	0.07692307692307693
# Generation #4:	W,ReNQZUoiKr!	0.15384615384615385
# Generation #5:	M,ReNQZUoiKr!	0.15384615384615385
# Generation #6:	M,RevQZUoiKr!	0.15384615384615385
# Generation #7:	M,RevQZUoi.r!	0.15384615384615385
# Generation #8:	M,RevQZUoi.d!	0.23076923076923078
# Generation #9:	M,mevQZUoi.d!	0.23076923076923078
# Generation #10:	M,mevQZUo .d!	0.23076923076923078
# Generation #11:	M,mevwZUo .d!	0.23076923076923078
# Generation #12:	M,mevwjUo .d!	0.23076923076923078
# Generation #13:	M,mevwjUo ld!	0.3076923076923077
# Generation #14:	M,levwjUo ld!	0.38461538461538464
# Generation #15:	M,levwjHo ld!	0.38461538461538464
# Generation #16:	M,levw Ho ld!	0.46153846153846156
# Generation #17:	H,levw Ho ld!	0.5384615384615384
# Generation #18:	H,lIvw Ho ld!	0.5384615384615384
# Generation #19:	H,lIv¡ Ho ld!	0.5384615384615384
# Generation #20:	H,lIv¡ Vo ld!	0.5384615384615384
# Generation #21:	HOlIv¡ Vo ld!	0.5384615384615384
# Generation #22:	HOlIv¡ Uo ld!	0.5384615384615384
# Generation #23:	HwlIv¡ Uo ld!	0.5384615384615384
# Generation #24:	HwlIv¡ to ld!	0.5384615384615384
# Generation #25:	HwlIv¡ toyld!	0.5384615384615384
# Generation #26:	HQlIv¡ toyld!	0.5384615384615384
# Generation #27:	HQlIvG toyld!	0.5384615384615384
# Generation #28:	HQlIvG toNld!	0.5384615384615384
# Generation #29:	H.lIvG toNld!	0.5384615384615384
# Generation #30:	HylIvG toNld!	0.5384615384615384
# Generation #31:	HylIkG toNld!	0.5384615384615384
# Generation #32:	HylIkG ,oNld!	0.5384615384615384
# Generation #33:	HylIEG ,oNld!	0.5384615384615384
# Generation #34:	HylIEG CoNld!	0.5384615384615384
# Generation #35:	HylKEG CoNld!	0.5384615384615384
# Generation #36:	H!lKEG CoNld!	0.5384615384615384
# Generation #37:	H!llEG CoNld!	0.6153846153846154
# Generation #38:	H!llEG Colld!	0.6153846153846154
# Generation #39:	HGllEG Colld!	0.6153846153846154
# Generation #40:	HGllEG Coold!	0.6153846153846154
# Generation #41:	HGll¡G Coold!	0.6153846153846154
# Generation #42:	HGll¡G Comld!	0.6153846153846154
# Generation #43:	HGll¡G Comld!	0.6153846153846154
# Generation #44:	HGll¡G Womld!	0.6153846153846154
# Generation #45:	HGll¡G WoFld!	0.6153846153846154
# Generation #46:	HGll¡G qoFld!	0.6153846153846154
# Generation #47:	HDll¡G qoFld!	0.6153846153846154
# Generation #48:	HDll¡G PoFld!	0.6153846153846154
# Generation #49:	HDll¡¡ PoFld!	0.6153846153846154
# Generation #50:	HDll¡¡ Porld!	0.6923076923076923
# Generation #51:	HDll¡¡ Uorld!	0.6923076923076923
# Generation #52:	HDll¡¡ morld!	0.6923076923076923
# Generation #53:	HÑll¡¡ morld!	0.6923076923076923
# Generation #54:	Hmll¡¡ morld!	0.6923076923076923
# Generation #55:	Hmllo¡ morld!	0.7692307692307693
# Generation #56:	Hmllo¡ .orld!	0.7692307692307693
# Generation #57:	Hmllot .orld!	0.7692307692307693
# Generation #58:	Hmllot .orld!	0.7692307692307693
# Generation #59:	Hgllot .orld!	0.7692307692307693
# Generation #60:	Hgllow .orld!	0.7692307692307693
# Generation #61:	Hgllow Borld!	0.7692307692307693
# Generation #62:	Hgllow Borld!	0.7692307692307693
# Generation #63:	Hgllow Borld!	0.7692307692307693
# Generation #64:	H!llow Borld!	0.7692307692307693
# Generation #65:	H!lloV Borld!	0.7692307692307693
# Generation #66:	H!lloq Borld!	0.7692307692307693
# Generation #67:	Hklloq Borld!	0.7692307692307693
# Generation #68:	HklloO Borld!	0.7692307692307693
# Generation #69:	HelloO Borld!	0.8461538461538461
# Generation #70:	HelloO vorld!	0.8461538461538461
# Generation #71:	HelloO vorld!	0.8461538461538461
# Generation #72:	HelloO world!	0.9230769230769231
# Generation #73:	HelloÑ world!	0.9230769230769231
# Generation #74:	HelloH world!	0.9230769230769231
# Generation #75:	Helloe world!	0.9230769230769231
# Generation #76:	Ielloe world!	0.8461538461538461
# Generation #77:	qelloe world!	0.8461538461538461
# Generation #78:	qelloo world!	0.8461538461538461
# Generation #79:	relloo world!	0.8461538461538461
# Generation #80:	felloo world!	0.8461538461538461
# Generation #81:	fblloo world!	0.7692307692307693
# Generation #82:	fblloZ world!	0.7692307692307693
# Generation #83:	fblloz world!	0.7692307692307693
# Generation #84:	gblloz world!	0.7692307692307693
# Generation #85:	mblloz world!	0.7692307692307693
# Generation #86:	mLlloz world!	0.7692307692307693
# Generation #87:	mLlloi world!	0.7692307692307693
# Generation #88:	MLlloi world!	0.7692307692307693
# Generation #89:	MOlloi world!	0.7692307692307693
# Generation #90:	Mqlloi world!	0.7692307692307693
# Generation #91:	Melloi world!	0.8461538461538461
# Generation #92:	Ielloi world!	0.8461538461538461
# Generation #93:	Iellox world!	0.8461538461538461
# Generation #94:	IelloQ world!	0.8461538461538461
# Generation #95:	IelloU world!	0.8461538461538461
# Generation #96:	NelloU world!	0.8461538461538461
# Generation #97:	NelloV world!	0.8461538461538461
# Generation #98:	NelloV world!	0.8461538461538461
# Generation #99:	NelloV world!	0.8461538461538461
# Generation #100:	NelloÑ world!	0.8461538461538461
# Generation #101:	Nello! world!	0.8461538461538461
# Generation #102:	Yello! world!	0.8461538461538461
# Generation #103:	dello! world!	0.8461538461538461
# Generation #104:	gello! world!	0.8461538461538461
# Generation #105:	Lello! world!	0.8461538461538461
# Generation #106:	Lello! world!	0.8461538461538461
# Generation #107:	LelloR world!	0.8461538461538461
# Generation #108:	LelloJ world!	0.8461538461538461
# Generation #109:	Lelloe world!	0.8461538461538461
# Generation #110:	ñelloe world!	0.8461538461538461
# Generation #111:	ñelloe worRd!	0.7692307692307693
# Generation #112:	Yelloe worRd!	0.7692307692307693
# Generation #113:	Yelloi worRd!	0.7692307692307693
# Generation #114:	Yelloi worMd!	0.7692307692307693
# Generation #115:	Yelloi worad!	0.7692307692307693
# Generation #116:	YelloC worad!	0.7692307692307693
# Generation #117:	YelloC worad!	0.7692307692307693
# Generation #118:	RelloC worad!	0.7692307692307693
# Generation #119:	helloC worad!	0.7692307692307693
# Generation #120:	zelloC worad!	0.7692307692307693
# Generation #121:	zelloC woryd!	0.7692307692307693
# Generation #122:	zelloC worid!	0.7692307692307693
# Generation #123:	LelloC worid!	0.7692307692307693
# Generation #124:	ielloC worid!	0.7692307692307693
# Generation #125:	ielloC worñd!	0.7692307692307693
# Generation #126:	ielloT worñd!	0.7692307692307693
# Generation #127:	HelloT worñd!	0.8461538461538461
# Generation #128:	HelloT worxd!	0.8461538461538461
# Generation #129:	Hello¡ worxd!	0.8461538461538461
# Generation #130:	Hello¡ worxdS	0.7692307692307693
# Generation #131:	Hello¡ worxdS	0.7692307692307693
# Generation #132:	Hello¡ woridS	0.7692307692307693
# Generation #133:	Hello¡ woridk	0.7692307692307693
# Generation #134:	Hello¡ woridn	0.7692307692307693
# Generation #135:	Hello¡ woridC	0.7692307692307693
# Generation #136:	Hello¡ woradC	0.7692307692307693
# Generation #137:	HelloJ woradC	0.7692307692307693
# Generation #138:	HelloJ wor!dC	0.7692307692307693
# Generation #139:	HelloJ wor!dl	0.7692307692307693
# Generation #140:	HelloJ worCdl	0.7692307692307693
# Generation #141:	HelloJ worCdñ	0.7692307692307693
# Generation #142:	Hello, worCdñ	0.8461538461538461
# Generation #143:	Hello, worCdv	0.8461538461538461
# Generation #144:	Hello, worfdv	0.8461538461538461
# Generation #145:	Hello, worFdv	0.8461538461538461
# Generation #146:	Hello, worddv	0.8461538461538461
# Generation #147:	Hello, worddv	0.8461538461538461
# Generation #148:	Hello, worudv	0.8461538461538461
# Generation #149:	Hello, worudS	0.8461538461538461
# Generation #150:	Hello, worudn	0.8461538461538461
# Generation #151:	Hello, worudW	0.8461538461538461
# Generation #152:	Hello, worudW	0.8461538461538461
# Generation #153:	Hello, worudo	0.8461538461538461
# Generation #154:	Hello, worudq	0.8461538461538461
# Generation #155:	Hello, worudE	0.8461538461538461
# Generation #156:	Hello, worudm	0.8461538461538461
# Generation #157:	Hello, worud,	0.8461538461538461
# Generation #158:	Hello, worWd,	0.8461538461538461
# Generation #159:	Hello, worWdP	0.8461538461538461
# Generation #160:	Hello, worAdP	0.8461538461538461
# Generation #161:	Hello, wor¡dP	0.8461538461538461
# Generation #162:	Hello, wor¡dP	0.8461538461538461
# Generation #163:	Hello, wor¡d,	0.8461538461538461
# Generation #164:	Hello, worDd,	0.8461538461538461
# Generation #165:	Hello, worgd,	0.8461538461538461
# Generation #166:	Hello, worgdv	0.8461538461538461
# Generation #167:	Hello, worgdi	0.8461538461538461
# Generation #168:	Hello, worgdi	0.8461538461538461
# Generation #169:	Hello, worgdc	0.8461538461538461
# Generation #170:	Hello, worDdc	0.8461538461538461
# Generation #171:	Hello, worDdr	0.8461538461538461
# Generation #172:	Hello, wor.dr	0.8461538461538461
# Generation #173:	Hello, wor.d 	0.8461538461538461
# Generation #174:	Hello, worGd 	0.8461538461538461
# Generation #175:	Hello, worGdi	0.8461538461538461
# Generation #176:	Hello, worYdi	0.8461538461538461
# Generation #177:	Hello, worYdH	0.8461538461538461
# Generation #178:	Hello, worodH	0.8461538461538461
# Generation #179:	Hello, worodx	0.8461538461538461
# Generation #180:	Hello, worodN	0.8461538461538461
# Generation #181:	Hello, worTdN	0.8461538461538461
# Generation #182:	Hello, worTdZ	0.8461538461538461
# Generation #183:	Hello, worFdZ	0.8461538461538461
# Generation #184:	Hello, worFdZ	0.8461538461538461
# Generation #185:	Hello, worFdd	0.8461538461538461
# Generation #186:	Hello, worFdZ	0.8461538461538461
# Generation #187:	Hello, woridZ	0.8461538461538461
# Generation #188:	Hello, woridq	0.8461538461538461
# Generation #189:	Hvllo, woridq	0.7692307692307693
# Generation #190:	Hvllo, woridy	0.7692307692307693
# Generation #191:	Hvllo, woridy	0.7692307692307693
# Generation #192:	Hvllo, worBdy	0.7692307692307693
# Generation #193:	Hvllo, worAdy	0.7692307692307693
# Generation #194:	Hvllo, worAdq	0.7692307692307693
# Generation #195:	Hvllo, worAdb	0.7692307692307693
# Generation #196:	Hvllo, worAde	0.7692307692307693
# Generation #197:	HDllo, worAde	0.7692307692307693
# Generation #198:	Hello, worAde	0.8461538461538461
# Generation #199:	Hello, worAde	0.8461538461538461
# Generation #200:	Hello, worAdi	0.8461538461538461
# Generation #201:	Hello, worAdk	0.8461538461538461
# Generation #202:	Hello, worAdL	0.8461538461538461
# Generation #203:	Hello, worAd!	0.9230769230769231
# Generation #204:	HelloQ worAd!	0.8461538461538461
# Generation #205:	HelloT worAd!	0.8461538461538461
# Generation #206:	Hellos worAd!	0.8461538461538461
# Generation #207:	Hellos worBd!	0.8461538461538461
# Generation #208:	Hellos worbd!	0.8461538461538461
# Generation #209:	Hellos worRd!	0.8461538461538461
# Generation #210:	Hellos wor¡d!	0.8461538461538461
# Generation #211:	Hellos wor¡d!	0.8461538461538461
# Generation #212:	Hellos worXd!	0.8461538461538461
# Generation #213:	HelloN worXd!	0.8461538461538461
# Generation #214:	HelloU worXd!	0.8461538461538461
# Generation #215:	WelloU worXd!	0.7692307692307693
# Generation #216:	helloU worXd!	0.7692307692307693
# Generation #217:	SelloU worXd!	0.7692307692307693
# Generation #218:	SelloU worbd!	0.7692307692307693
# Generation #219:	SelloB worbd!	0.7692307692307693
# Generation #220:	SelloB wortd!	0.7692307692307693
# Generation #221:	qelloB wortd!	0.7692307692307693
# Generation #222:	qelloQ wortd!	0.7692307692307693
# Generation #223:	qellot wortd!	0.7692307692307693
# Generation #224:	qellot worpd!	0.7692307692307693
# Generation #225:	Pellot worpd!	0.7692307692307693
# Generation #226:	Pellog worpd!	0.7692307692307693
# Generation #227:	Pellop worpd!	0.7692307692307693
# Generation #228:	,ellop worpd!	0.7692307692307693
# Generation #229:	,ellop worsd!	0.7692307692307693
# Generation #230:	,ellop worod!	0.7692307692307693
# Generation #231:	,ellop worpd!	0.7692307692307693
# Generation #232:	Fellop worpd!	0.7692307692307693
# Generation #233:	Fellop world!	0.8461538461538461
# Generation #234:	Felloz world!	0.8461538461538461
# Generation #235:	Felloz world!	0.8461538461538461
# Generation #236:	Fello, world!	0.9230769230769231
# Generation #237:	Fello, world!	0.9230769230769231
# Generation #238:	Dello, world!	0.9230769230769231
# Generation #239:	Dello, wMrld!	0.8461538461538461
# Generation #240:	uello, wMrld!	0.8461538461538461
# Generation #241:	uello, wzrld!	0.8461538461538461
# Generation #242:	Dello, wzrld!	0.8461538461538461
# Generation #243:	Qello, wzrld!	0.8461538461538461
# Generation #244:	Sello, wzrld!	0.8461538461538461
# Generation #245:	Sello, wirld!	0.8461538461538461
# Generation #246:	Sello, wnrld!	0.8461538461538461
# Generation #247:	Sello, wnrld!	0.8461538461538461
# Generation #248:	zello, wnrld!	0.8461538461538461
# Generation #249:	zello, wÑrld!	0.8461538461538461
# Generation #250:	zello, wnrld!	0.8461538461538461
# Generation #251:	zeylo, wnrld!	0.7692307692307693
# Generation #252:	zeTlo, wnrld!	0.7692307692307693
# Generation #253:	zeTlo, wUrld!	0.7692307692307693
# Generation #254:	HeTlo, wUrld!	0.8461538461538461
# Generation #255:	Henlo, wUrld!	0.8461538461538461
# Generation #256:	Henlo, wtrld!	0.8461538461538461
# Generation #257:	Henlo, wPrld!	0.8461538461538461
# Generation #258:	Henlo, wzrld!	0.8461538461538461
# Generation #259:	Henlo, wYrld!	0.8461538461538461
# Generation #260:	Heklo, wYrld!	0.8461538461538461
# Generation #261:	HeIlo, wYrld!	0.8461538461538461
# Generation #262:	Hello, wYrld!	0.9230769230769231
# Generation #263:	Hello, werld!	0.9230769230769231
# Generation #264:	Hello, werld!	0.9230769230769231
# Generation #265:	Hello, werlk!	0.8461538461538461
# Generation #266:	Hello, werUk!	0.7692307692307693
# Generation #267:	Hello, werCk!	0.7692307692307693
# Generation #268:	Hello, werhk!	0.7692307692307693
# Generation #269:	Hello, wGrhk!	0.7692307692307693
# Generation #270:	Hello, wGrdk!	0.7692307692307693
# Generation #271:	Hello, wGrdX!	0.7692307692307693
# Generation #272:	Hello, wGrdJ!	0.7692307692307693
# Generation #273:	Hello, wGrlJ!	0.8461538461538461
# Generation #274:	Hello, wGrlm!	0.8461538461538461
# Generation #275:	Hello, wGrld!	0.9230769230769231
# Generation #276:	Hello, wbrld!	0.9230769230769231
# Generation #277:	Hello, wbrld!	0.9230769230769231
# Generation #278:	Hello, wgrld!	0.9230769230769231
# Generation #279:	Hello, wgrld!	0.9230769230769231
# Generation #280:	Hello, wbrld!	0.9230769230769231
# Generation #281:	Hello, wGrld!	0.9230769230769231
# Generation #282:	Hello, wsrld!	0.9230769230769231
# Generation #283:	Hello, wsrld!	0.9230769230769231
# Generation #284:	Hello, wsrld!	0.9230769230769231
# Generation #285:	Hello, wvrld!	0.9230769230769231
# Generation #286:	H llo, wvrld!	0.8461538461538461
# Generation #287:	H llo, wbrld!	0.8461538461538461
# Generation #288:	H llo, wGrld!	0.8461538461538461
# Generation #289:	HLllo, wGrld!	0.8461538461538461
# Generation #290:	Hxllo, wGrld!	0.8461538461538461
# Generation #291:	Hgllo, wGrld!	0.8461538461538461
# Generation #292:	Hgllo, wÑrld!	0.8461538461538461
# Generation #293:	Hgllo, wBrld!	0.8461538461538461
# Generation #294:	Hgllo, w!rld!	0.8461538461538461
# Generation #295:	HEllo, w!rld!	0.8461538461538461
# Generation #296:	HEllo, world!	0.9230769230769231
# Generation #297:	HEllo, aorld!	0.8461538461538461
# Generation #298:	HEllo, Borld!	0.8461538461538461
# Generation #299:	HEllo,ZBorld!	0.7692307692307693
# Generation #300:	HEllo,DBorld!	0.7692307692307693
# Generation #301:	HEllo,Drorld!	0.7692307692307693
# Generation #302:	Hullo,Drorld!	0.7692307692307693
# Generation #303:	HAllo,Drorld!	0.7692307692307693
# Generation #304:	HAllo, rorld!	0.8461538461538461
# Generation #305:	HAllo, gorld!	0.8461538461538461
# Generation #306:	H¡llo, gorld!	0.8461538461538461
# Generation #307:	H¡llo, ,orld!	0.8461538461538461
# Generation #308:	H¡llo, aorld!	0.8461538461538461
# Generation #309:	H¡llo, world!	0.9230769230769231
# Generation #310:	HDllo, world!	0.9230769230769231
# Generation #311:	HDlSo, world!	0.8461538461538461
# Generation #312:	HDllo, world!	0.9230769230769231
# Generation #313:	HIllo, world!	0.9230769230769231
# Generation #314:	HIllo, world!	0.9230769230769231
# Generation #315:	HGllo, world!	0.9230769230769231
# Generation #316:	HGllo, world!	0.9230769230769231
# Generation #317:	HPllo, world!	0.9230769230769231
# Generation #318:	HYllo, world!	0.9230769230769231
# Generation #319:	Htllo, world!	0.9230769230769231
# Generation #320:	Htllo, world!	0.9230769230769231
# Generation #321:	Hwllo, world!	0.9230769230769231
# Generation #322:	Hwllo, world!	0.9230769230769231
# Generation #323:	HZllo, world!	0.9230769230769231
# Generation #324:	Hñllo, world!	0.9230769230769231
# Hello, world! 1.0
